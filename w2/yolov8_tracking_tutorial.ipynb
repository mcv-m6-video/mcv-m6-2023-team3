# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/yolov8_tracking.git  # clone repo
# %pip install -qr requirements.txt  # install dependencies
# %pip install thop                  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.13.1+cu116 (CPU)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# %cd /content/yolov8_tracking

# get the test video from the repo
# !wget -nc https://github.com/mikel-brostrom/yolov8_tracking/releases/download/v.2.0/test.avi
# extract 3 seconds worth of video frames of it
# !yes | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:01 -vf fps=30 out.avi
# Out:
# /content/yolov8_tracking
# File ‘test.avi’ already there; not retrieving.
#
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, matroska,webm, from 'test.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ENCODER         : Lavf57.83.100
#   Duration: 00:00:35.00, start: 0.000000, bitrate: 1164 kb/s
#     Stream #0:0: Video: vp9 (Profile 0), yuv420p(tv, progressive), 960x540, SAR 1:1 DAR 16:9, 30 fps, 30 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       ENCODER         : Lavc57.107.100 libvpx-vp9
#       DURATION        : 00:00:35.000000000
# File 'out.avi' already exists. Overwrite ? [y/N] Stream mapping:
#   Stream #0:0 -> #0:0 (vp9 (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, avi, to 'out.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (FMP4 / 0x34504D46), yuv420p, 960x540 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       DURATION        : 00:00:35.000000000
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   30 fps=0.0 q=18.0 Lsize=     129kB time=00:00:01.00 bitrate=1055.1kbits/s speed=3.81x
# video:122kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.182988%

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo-weights yolov8s.pt --reid-weights osnet_x0_25_msmt17.pt --source out.avi --save-vid
# Out:
# track: yolo_weights=[PosixPath('yolov8s.pt')], reid_weights=osnet_x0_25_msmt17.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=out.avi, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# video 1/1 (1/30) /content/yolov8_tracking/out.avi: 384x640 13 persons, 1 car, 1 motorcycle, 365.3ms
# video 1/1 (2/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 358.8ms
# video 1/1 (3/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 355.4ms
# video 1/1 (4/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 352.6ms
# video 1/1 (5/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 355.4ms
# video 1/1 (6/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 348.7ms
# video 1/1 (7/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 1 backpack, 346.6ms
# video 1/1 (8/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 1 backpack, 350.7ms
# video 1/1 (9/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 1 backpack, 362.2ms
# video 1/1 (10/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 1 backpack, 342.1ms
# video 1/1 (11/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 344.4ms
# video 1/1 (12/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 337.8ms
# video 1/1 (13/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 347.5ms
# video 1/1 (14/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 357.4ms
# video 1/1 (15/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 362.3ms
# video 1/1 (16/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 372.9ms
# video 1/1 (17/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 347.2ms
# video 1/1 (18/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 345.9ms
# video 1/1 (19/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 1 motorcycle, 358.4ms
# video 1/1 (20/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 1 motorcycle, 347.1ms
# video 1/1 (21/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 1 motorcycle, 344.7ms
# video 1/1 (22/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 1 motorcycle, 353.7ms
# video 1/1 (23/30) /content/yolov8_tracking/out.avi: 384x640 8 persons, 1 car, 1 motorcycle, 343.3ms
# video 1/1 (24/30) /content/yolov8_tracking/out.avi: 384x640 9 persons, 1 car, 1 motorcycle, 335.1ms
# video 1/1 (25/30) /content/yolov8_tracking/out.avi: 384x640 10 persons, 1 car, 1 motorcycle, 353.8ms
# video 1/1 (26/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 341.9ms
# video 1/1 (27/30) /content/yolov8_tracking/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 340.6ms
# video 1/1 (28/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 351.3ms
# video 1/1 (29/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 343.1ms
# video 1/1 (30/30) /content/yolov8_tracking/out.avi: 384x640 11 persons, 1 car, 1 motorcycle, 344.4ms
# Speed: 0.8ms pre-process, 345.6ms inference, 1.1ms NMS, 2.9ms bytetrack update per image at shape (1, 3, 640, 640)
# Results saved to runs/track/exp

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# https://stackoverflow.com/questions/57377185/how-play-mp4-video-in-google-colab
#
# Compress the video file to a format supported by Google Colab (mpeg4 (native) -> h264 (libx264))

# %%
# !ffmpeg -i /content/yolov8_tracking/runs/track/exp/out.mp4 -vf fps=30 -vcodec libx264 output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/yolov8_tracking/runs/track/exp/out.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.00, start: 0.000000, bitrate: 2866 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 960x540 [SAR 1:1 DAR 16:9], 2858 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e2dcc31f80] using SAR=1/1
# [libx264 @ 0x55e2dcc31f80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e2dcc31f80] profile High, level 3.1
# [libx264 @ 0x55e2dcc31f80] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 960x540 [SAR 1:1 DAR 16:9], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   30 fps=0.0 q=-1.0 Lsize=     189kB time=00:00:00.90 bitrate=1722.8kbits/s speed=1.25x
# video:188kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.521195%
# [libx264 @ 0x55e2dcc31f80] frame I:1     Avg QP:21.68  size: 47700
# [libx264 @ 0x55e2dcc31f80] frame P:27    Avg QP:24.13  size:  5169
# [libx264 @ 0x55e2dcc31f80] frame B:2     Avg QP:27.88  size:  2442
# [libx264 @ 0x55e2dcc31f80] consecutive B-frames: 90.0%  0.0% 10.0%  0.0%
# [libx264 @ 0x55e2dcc31f80] mb I  I16..4: 14.4% 79.5%  6.1%
# [libx264 @ 0x55e2dcc31f80] mb P  I16..4:  2.2%  5.3%  0.6%  P16..4: 15.2%  5.1%  3.5%  0.0%  0.0%    skip:68.1%
# [libx264 @ 0x55e2dcc31f80] mb B  I16..4:  0.3%  1.0%  0.1%  B16..8: 30.6%  3.0%  0.6%  direct: 1.2%  skip:63.2%  L0:81.7% L1: 6.5% BI:11.7%
# [libx264 @ 0x55e2dcc31f80] 8x8 transform intra:70.1% inter:79.7%
# [libx264 @ 0x55e2dcc31f80] coded y,uvDC,uvAC intra: 53.7% 57.7% 16.9% inter: 6.8% 9.4% 4.7%
# [libx264 @ 0x55e2dcc31f80] i16 v,h,dc,p: 35% 40% 24%  1%
# [libx264 @ 0x55e2dcc31f80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 23% 38%  4%  2%  3%  1%  3%  5%
# [libx264 @ 0x55e2dcc31f80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 41% 25% 11%  3%  4%  5%  3%  5%  4%
# [libx264 @ 0x55e2dcc31f80] i8c dc,h,v,p: 39% 31% 28%  2%
# [libx264 @ 0x55e2dcc31f80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e2dcc31f80] ref P L0: 70.7% 10.3% 12.4%  6.6%
# [libx264 @ 0x55e2dcc31f80] ref B L0: 75.7% 18.8%  5.5%
# [libx264 @ 0x55e2dcc31f80] kb/s:1537.10

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
